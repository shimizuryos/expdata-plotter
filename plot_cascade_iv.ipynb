# %%
! pip install pandas

# %%
from src import parse_iv_csv, plot_iv_series, plot_grouped_iv_series, load_iv_data

# %%
iv_4_file_path = '/Volumes/NO NAME/251112 CoFe/251112 CoFe RT cascade at 1125/IV RT/IV(resister) [251112CoFe 17-8-d RT(9) ; 11_25_2025 11_20_05 AM].csv'
iv_4_name = "17-8-d RT"
iv_5_file_path = '/Volumes/NO NAME/251112 CoFe/251112 CoFe RT cascade at 1125/IV RT/IV(resister) [251112CoFe 18-8-d RT(8) ; 11_25_2025 11_15_23 AM].csv'
iv_5_name = "18-8-d RT"
iv_6_file_path = '/Volumes/NO NAME/251112 CoFe/251112 CoFe RT cascade at 1125/IV RT/IV(resister) [251112CoFe 19-8-d RT(7) ; 11_25_2025 11_14_17 AM].csv'
iv_6_name = "19-8-d RT"

iv_1_file_path = '/Volumes/NO NAME/251112 CoFe/251112 CoFe RT cascade at 1125/IV RT/IV(resister) [251112CoFe 2-8-d RT(24) ; 11_25_2025 11_39_09 AM].csv'
iv_1_name = "2-8-d RT"
iv_2_file_path = '/Volumes/NO NAME/251112 CoFe/251112 CoFe RT cascade at 1125/IV RT/IV(resister) [251112CoFe 3-8-d RT(23) ; 11_25_2025 11_37_54 AM].csv'
iv_2_name = "3-8-d RT"
iv_3_file_path = '/Volumes/NO NAME/251112 CoFe/251112 CoFe RT cascade at 1125/IV RT/IV(resister) [251112CoFe 4-8-d RT(22) ; 11_25_2025 11_36_44 AM].csv'
iv_3_name = "4-8-d RT"

file_paths = [iv_1_file_path, iv_2_file_path, iv_3_file_path, iv_4_file_path, iv_5_file_path, iv_6_file_path]
names = [iv_1_name, iv_2_name, iv_3_name, iv_4_name, iv_5_name, iv_6_name]

iv_series_list = [parse_iv_csv(file_path) for file_path in file_paths]
plot_iv_series(iv_series_list, names)
# Out:
# (<Figure size 2000x800 with 2 Axes>,
#  <Axes: title={'center': 'IV'}, xlabel='Vd (mV)', ylabel='Id (mA)'>,
#  <Axes: title={'center': 'RV'}, xlabel='Vd (mV)', ylabel='R (ohm)'>)

# %%
iv_4_file_path = '/Volumes/NO NAME/251112 CoFe/251112 CoFe RT cascade at 1125/IV RT/IV(resister) [251112CoFe 17-8-d RT(9) ; 11_25_2025 11_20_05 AM].csv'
iv_4_name = "17-8-d RT"
iv_5_file_path = '/Volumes/NO NAME/251112 CoFe/251112 CoFe RT cascade at 1125/IV RT/IV(resister) [251112CoFe 18-8-d RT(8) ; 11_25_2025 11_15_23 AM].csv'
iv_5_name = "18-8-d RT"
iv_6_file_path = '/Volumes/NO NAME/251112 CoFe/251112 CoFe RT cascade at 1125/IV RT/IV(resister) [251112CoFe 19-8-d RT(7) ; 11_25_2025 11_14_17 AM].csv'
iv_6_name = "19-8-d RT"

iv_1_file_path = '/Volumes/NO NAME/251112 CoFe/251112 CoFe RT cascade at 1125/IV RT/IV(resister) [251112CoFe 2-8-d RT(24) ; 11_25_2025 11_39_09 AM].csv'
iv_1_name = "2-8-d RT"
iv_2_file_path = '/Volumes/NO NAME/251112 CoFe/251112 CoFe RT cascade at 1125/IV RT/IV(resister) [251112CoFe 3-8-d RT(23) ; 11_25_2025 11_37_54 AM].csv'
iv_2_name = "3-8-d RT"
iv_3_file_path = '/Volumes/NO NAME/251112 CoFe/251112 CoFe RT cascade at 1125/IV RT/IV(resister) [251112CoFe 4-8-d RT(22) ; 11_25_2025 11_36_44 AM].csv'
iv_3_name = "4-8-d RT"

iv_7_file_path = '/Volumes/NO NAME/251112 CoFe/251112 CoFe RT cascade at 1125/IV RT/IV(resister) [251112CoFe 8-8-d RT(33) ; 11_25_2025 11_52_43 AM].csv'    
iv_7_name = "8-8-d RT"
iv_8_file_path = '/Volumes/NO NAME/251112 CoFe/251112 CoFe RT cascade at 1125/IV RT/IV(resister) [251112CoFe 9-8-d RT(17) ; 11_25_2025 11_31_12 AM].csv'
iv_8_name = "9-8-d RT"
iv_9_file_path = '/Volumes/NO NAME/251112 CoFe/251112 CoFe RT cascade at 1125/IV RT/IV(resister) [251112CoFe 10-8-d RT(16) ; 11_25_2025 11_28_25 AM].csv'
iv_9_name = "10-8-d RT"

group1 = [iv_1_file_path, iv_2_file_path, iv_3_file_path]
iv_series1_list = [parse_iv_csv(file_path) for file_path in group1]
group2 = [iv_4_file_path, iv_5_file_path, iv_6_file_path]
iv_series2_list = [parse_iv_csv(file_path) for file_path in group2]
group3 = [iv_7_file_path, iv_8_file_path, iv_9_file_path]
iv_series3_list = [parse_iv_csv(file_path) for file_path in group3]
group = [iv_series1_list, iv_series2_list, iv_series3_list]

group1_names = [iv_1_name, iv_2_name, iv_3_name]
group2_names = [iv_4_name, iv_5_name, iv_6_name]
group3_names = [iv_7_name, iv_8_name, iv_9_name]
group_names = [group1_names, group2_names, group3_names]

plot_grouped_iv_series(group, group_names)
# Out:
# (<Figure size 2000x800 with 2 Axes>,
#  <Axes: title={'center': 'IV'}, xlabel='Vd (mV)', ylabel='Id (mA)'>,
#  <Axes: title={'center': 'RV'}, xlabel='Vd (mV)', ylabel='R (ohm)'>)

# %%
file_0918_3 = '/Volumes/NO NAME/20250918 CoFe 3T/251106/IV/20251106_103945_5-10-d 300K'
name_0918_3 = '0918 5-10d RT'
file_0918_1 = '/Volumes/NO NAME/20250918 CoFe 3T/251106/IV/20251106_104352_3-10-d 300K'
name_0918_1 = '0918 3-10d RT'
file_0918_2 = '/Volumes/NO NAME/20250918 CoFe 3T/251106/IV/20251106_104238_4-10-d 300K'
name_0918_2 = '0918 4-10d RT'
data_0918_list = [load_iv_data(file_0918_1), load_iv_data(file_0918_2), load_iv_data(file_0918_3)]
labels_0918 = [name_0918_1, name_0918_2, name_0918_3]
plot_iv_series(data_0918_list, labels_0918)

labels_1112_1 = ['1112 2-8-d RT', '1112 3-8-d RT', '1112 4-8-d RT']
data1_1112 = iv_series1_list
labels_1112_2 = ['1112 17-8-d RT', '1112 18-8-d RT', '1112 19-8-d RT']
data2_1112 = iv_series2_list

datas1 = [data1_1112, data_0918_list]
labels1 = [labels_1112_1, labels_0918]
plot_grouped_iv_series(datas1, labels1)

datas2 = [data2_1112, data_0918_list]
labels2 = [labels_1112_2, labels_0918]
plot_grouped_iv_series(datas2, labels2)

datas_all = [data1_1112, data2_1112, data_0918_list]
labels_all = [labels_1112_1, labels_1112_2, labels_0918]
plot_grouped_iv_series(datas_all, labels_all)
# Out:
# (<Figure size 2000x800 with 2 Axes>,
#  <Axes: title={'center': 'IV'}, xlabel='Vd (mV)', ylabel='Id (mA)'>,
#  <Axes: title={'center': 'RV'}, xlabel='Vd (mV)', ylabel='R (ohm)'>)
