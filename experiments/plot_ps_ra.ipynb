# %%
from distributed.protocol.cupy import n
yaml_path = "data/ps_ra_data.yaml"
with open(yaml_path, "r", encoding="utf-8") as f:
    payload = yaml.safe_load(f)

# データ抽出
series_list = load_ps_ra_data(yaml_path)

# プロット
fig, ax = plot_ra_ps_summary(
    series_list=series_list,
    title="RA vs Ps",
    ylim=(0, 30)
)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from distributed.protocol.cupy import n
#       2 yaml_path = "data/ps_ra_data.yaml"
#       3 with open(yaml_path, "r", encoding="utf-8") as f:
#
# ModuleNotFoundError: No module named 'distributed'
