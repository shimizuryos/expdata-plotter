# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../backend")))
from src.services.hanle_service import calc_hanle_n_only_rms_from_files

file_paths = [
    '/Volumes/NO NAME/20250918 CoFe 3T/251016/Hanle/N3T_B3T_fitting_20251023_011552_20251016_160107 10-11-c 4K 300-10 90deg -10mA 0.40V 0.39V 300-10_averaged_N_only.txt',
    '/Volumes/NO NAME/20250918 CoFe 3T/251016/Hanle/N3T_B3T_fitting_20251016_135051_12-10-c 4K 90deg -10mA 0.48V 0.47V narrow 300-10_N_only.txt',
    '/Volumes/NO NAME/20250918 CoFe 3T/251016/Hanle/N3T_B3T_fitting_20251016_170215_11-13-c 4K 90deg -18mA 0.52V 0.51V_N_only.txt',
    '/Volumes/NO NAME/20250918 CoFe 3T/251031/Hanle/N3T_B3T_fitting_20251031_202223_7-10-c Mg2nm 4K -100mA 0.51V 0.44V_N_only.txt',
    '/Volumes/NO NAME/20250918 CoFe 3T/251031/Hanle/N3T_B3T_fitting_20251031_191933_8-10-c Mg2nm 4K -45mA 0.54V 0.51V_N_only.txt',
    '/Volumes/NO NAME/20250918 CoFe 3T/260107/Hanle/N3T_B3T_fitting_20260109_183937_18-11-c Mg2nm 4K  -4.7mA 0.61V 0.60V 90deg 140loop n_width_fix_60Oe_N_only.txt',
    '/Volumes/NO NAME/20250918 CoFe 3T/260107/Hanle/N3T_B3T_fitting_20260113_191810_18-10-c Mg2nm 6K  -6.2mA 0.67V 0.65V 90deg 125loop_N_only.txt',
    '/Volumes/NO NAME/20250918 CoFe 3T/260107/Hanle/N3T_B3T_fitting_20260115_191836_19-11-c Mg2nm 4K  -6.7mA 0.67V 0.65V 90deg 150loop_N_only.txt',
    '/Volumes/NO NAME/20250918 CoFe 3T/260107/Hanle/N3T_B3T_fitting_20260119_191055_18-12-c Mg2nm 4K  -6.8mA 0.66V 0.65V 90deg 130loop 60Oe width_fixed_N_only.txt',
]

calc_hanle_n_only_rms_from_files(file_paths)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       2 import os
#       3 sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../backend")))
# ----> 4 from src.services.hanle_service import calc_hanle_n_only_rms_from_files
#       6 file_paths = [
#       7     '/Volumes/NO NAME/20250918 CoFe 3T/251016/Hanle/N3T_B3T_fitting_20251023_011552_20251016_160107 10-11-c 4K 300-10 90deg -10mA 0.40V 0.39V 300-10_averaged_N_only.txt',
#       8     '/Volumes/NO NAME/20250918 CoFe 3T/251016/Hanle/N3T_B3T_fitting_20251016_135051_12-10-c 4K 90deg -10mA 0.48V 0.47V narrow 300-10_N_only.txt',
#    (...)     15     '/Volumes/NO NAME/20250918 CoFe 3T/260107/Hanle/N3T_B3T_fitting_20260119_191055_18-12-c Mg2nm 4K  -6.8mA 0.66V 0.65V 90deg 130loop 60Oe width_fixed_N_only.txt',
#      16 ]
#      18 calc_hanle_n_only_rms_from_files(file_paths)
#
# ...
